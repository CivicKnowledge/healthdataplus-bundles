# %% [markdown]
# # Chronic Disease Collection
#
# Chronic Disease Collection

# %%
import ambry.jupyter
from ambry import get_library
l = get_library()
b = l.bundle('ucla.edu-askchisne-hdp-0.0.1')

# %%
w = b.warehouse('foobar')

# %%
# %%warehouse_query w
#
# CREATE VIEW foo AS
# SELECT 'foo' as foo
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-3-759afdc666f2> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'warehouse_query', u'w', u"\nCREATE VIEW foo AS\nSELECT 'foo' as foo")
#
# /Users/eric/proj/virt/ambry-develop/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2291             magic_arg_s = self.var_expand(line, stack_depth)
#    2292             with self.builtin_trap:
# -> 2293                 result = fn(magic_arg_s, cell)
#    2294             return result
#    2295
#
# /Users/eric/proj/virt/ambry-develop/ambry/ambry/jupyter.py in warehouse_query(line, cell)
#      18     w = get_ipython().ev(w_var_name)
#      19
# ---> 20     w.query(cell).close()
#
# /Users/eric/proj/virt/ambry-develop/ambry/ambry/library/warehouse.pyc in query(self, asql, logger)
# ...
